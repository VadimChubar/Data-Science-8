# %%
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("2017_jun_final.csv")
df

# %%
# Прочитайте отриману таблицю, використовуючи метод head

df.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
# 3                               400   Одесса      до 200 человек  ...
# 4                               500   Другой       до 10 человек  ...
#
#   Еще.студент Уровень.английского                    Предметная.область  \
# 0        True       ниже среднего                         iOS,eCommerce
# 1        True       выше среднего                        Веб-разработка
# 2       False             средний  Веб-разработка,Корпоративные системы
# 3       False       ниже среднего   Desktop Applications,Веб-разработка
# 4       False             средний   Desktop Applications,Веб-разработка
#
#        Дата.заполнения                                         User.Agent  \
# 0  12/06/2017 12:38:08  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  12/06/2017 12:42:51  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...
# 2  12/06/2017 13:02:47  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3  12/06/2017 13:03:01  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 4  12/06/2017 13:03:47  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...
#
#     exp current_job_exp salary Валюта  cls
# 0   0.5             0.5    400    NaN   QA
# 1   0.0             0.0    430    NaN   QA
# 2   4.0             1.0   2500    NaN  DEV
# 3   5.0             4.0   2000    NaN  DEV
# 4  10.0             0.5   4500    NaN  DEV
#
# [5 rows x 25 columns]

# %%
# Визначте розмір таблиці за допомогою методу shape

df.shape
# Out:
# (8704, 25)

# %%
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

df.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object

# %%
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

cnt = df.isnull().sum(axis=0)*100/8704
cnt.round(3)
# Out:
# N                                    0.000
# Должность                            0.000
# Язык.программирования               44.233
# Специализация                       82.939
# Общий.опыт.работы                    0.000
# Опыт.работы.на.текущем.месте         0.000
# Зарплата.в.месяц                     0.000
# Изменение.зарплаты.за.12.месяцев     0.000
# Город                                0.000
# Размер.компании                      0.000
# Тип.компании                         0.000
# Пол                                  0.000
# Возраст                              0.000
# Образование                          0.000
# Университет                          4.113
# Еще.студент                          0.000
# Уровень.английского                  0.000
# Предметная.область                   2.562
# Дата.заполнения                      0.000
# User.Agent                           0.000
# exp                                  0.000
# current_job_exp                      0.000
# salary                               0.000
# Валюта                              99.885
# cls                                 18.084
# dtype: float64

# %%
# Видаліть усі стовпці з пропусками, крім стовпця Язык.программирования

df_tmp = df.isna().any()
col_not_del = ['Язык.программирования']
df_tmp[col_not_del] = False
df.drop(df_tmp.index[df_tmp], axis=1, inplace=True)

# %%
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець 
# "Мова.програмування"

cnt = df.isnull().sum(axis=0)*100/8704
cnt.round(3)
# Out:
# N                                    0.000
# Должность                            0.000
# Язык.программирования               44.233
# Общий.опыт.работы                    0.000
# Опыт.работы.на.текущем.месте         0.000
# Зарплата.в.месяц                     0.000
# Изменение.зарплаты.за.12.месяцев     0.000
# Город                                0.000
# Размер.компании                      0.000
# Тип.компании                         0.000
# Пол                                  0.000
# Возраст                              0.000
# Образование                          0.000
# Еще.студент                          0.000
# Уровень.английского                  0.000
# Дата.заполнения                      0.000
# User.Agent                           0.000
# exp                                  0.000
# current_job_exp                      0.000
# salary                               0.000
# dtype: float64

# %%
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

df = df.dropna()
df.head()
# Out:
#    N                 Должность Язык.программирования Общий.опыт.работы  \
# 2  3         Software Engineer               C#/.NET                 4
# 3  4         Software Engineer            JavaScript                 5
# 4  5  Senior Software Engineer            JavaScript    10 и более лет
# 6  7  Junior Software Engineer               C#/.NET                 1
# 7  8  Senior Software Engineer                   C++                 6
#
#   Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 2                            1              2500
# 3                            4              2000
# 4                          0.5              4500
# 6             меньше 3 месяцев               600
# 7                            1              3300
#
#    Изменение.зарплаты.за.12.месяцев        Город  Размер.компании  \
# 2                               800         Киев  до 1000 человек
# 3                               400       Одесса   до 200 человек
# 4                               500       Другой    до 10 человек
# 6                               100  Хмельницкий    до 50 человек
# 7                               500         Киев    до 10 человек
#
#      Тип.компании      Пол  Возраст         Образование  Еще.студент  \
# 2  Аутсорсинговая  мужской       26              Высшее        False
# 3     Продуктовая  мужской       30             Среднее        False
# 4     Продуктовая  мужской       30  Техникум / Колледж        False
# 6  Аутсорсинговая  мужской       23              Высшее        False
# 7     Продуктовая  мужской       28              Высшее        False
#
#   Уровень.английского      Дата.заполнения  \
# 2             средний  12/06/2017 13:02:47
# 3       ниже среднего  12/06/2017 13:03:01
# 4             средний  12/06/2017 13:03:47
# 6       ниже среднего  12/06/2017 13:04:26
# 7       выше среднего  12/06/2017 13:04:27
#
#                                           User.Agent   exp  current_job_exp  \
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0              1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0              4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0              0.5
# 6  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.0              0.0
# 7  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:53....   6.0              1.0
#
#    salary
# 2    2500
# 3    2000
# 4    4500
# 6     600
# 7    3300

# %%
# Визначте новий розмір таблиці за допомогою методу shape
df.shape
# Out:
# (4854, 20)

# %%
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

df.groupby('Должность').head()
# Out:
#          N                      Должность Язык.программирования  \
# 2        3              Software Engineer               C#/.NET
# 3        4              Software Engineer            JavaScript
# 4        5       Senior Software Engineer            JavaScript
# 6        7       Junior Software Engineer               C#/.NET
# 7        8       Senior Software Engineer                   C++
# 8        9       Junior Software Engineer                  Java
# 11      12               System Architect                 Scala
# 12      13              Software Engineer                Python
# 14      15              Software Engineer            Ruby/Rails
# 15      16       Senior Software Engineer            JavaScript
# 16      17              Software Engineer            JavaScript
# 17      18       Junior Software Engineer               C#/.NET
# 18      19       Senior Software Engineer                   C++
# 24      25       Senior Software Engineer                 Swift
# 35      36       Junior Software Engineer                  Java
# 40      41       Junior Software Engineer                 Swift
# 44      45                 Technical Lead                  Perl
# 52      53                 Technical Lead                   C++
# 54      55                 Technical Lead                   PHP
# 111    112                 Technical Lead                     C
# 219    220                 Technical Lead                   SQL
# 480    481               System Architect                  Java
# 730    731               System Architect               C#/.NET
# 733    734               System Architect                   C++
# 1135  1136               System Architect               C#/.NET
# 1706  1707  Data Scientist / Data Analyst                  Java
# 2049  2050                     HTML coder            JavaScript
# 2911  2912                         DevOps                Golang
# 2936  2937                     HTML coder            JavaScript
# 3097  3098                     HTML coder            JavaScript
# 4098  4099                Product Manager                Delphi
# 4315  4316                     HTML coder            JavaScript
# 5105  5106                      Team lead                   PHP
# 6304  6305                     HTML coder                   PHP
# 6712  6713                      ERP / CRM                   PHP
# 7004  7005                      Team lead               C#/.NET
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 2                    4                            1              2500
# 3                    5                            4              2000
# 4       10 и более лет                          0.5              4500
# 6                    1             меньше 3 месяцев               600
# 7                    6                            1              3300
# 8                  0.5                          0.5               550
# 11      10 и более лет                            1              5600
# 12                   1             меньше 3 месяцев               800
# 14                   3                            1              2500
# 15                   5                            5              2900
# 16                   4                            1              2875
# 17                   1                            1               574
# 18                   4                          0.5              3300
# 24                   6                            1              2800
# 35                   1                            1               350
# 40                   3                          1.5               450
# 44                   6                            4              3400
# 52      10 и более лет                            4              4500
# 54                   6                            3              3000
# 111     10 и более лет               10 и более лет              4150
# 219     10 и более лет                            4              3000
# 480     10 и более лет                            7              4300
# 730     10 и более лет                            5              4000
# 733     10 и более лет                            2              4500
# 1135                 6                            5              3600
# 1706               1.5             меньше 3 месяцев              2700
# 2049                 1                          0.5               400
# 2911                 8             меньше 3 месяцев              7000
# 2936                 1                          0.5               400
# 3097                 2                            1               600
# 4098                 7                            7              3000
# 4315               0.5                          0.5               385
# 5105                 7                            4              4000
# 6304                 4             меньше 3 месяцев               500
# 6712                 2                            1              2000
# 7004                 5                            5              2500
#
#       Изменение.зарплаты.за.12.месяцев        Город     Размер.компании  \
# 2                                  800         Киев     до 1000 человек
# 3                                  400       Одесса      до 200 человек
# 4                                  500       Другой       до 10 человек
# 6                                  100  Хмельницкий       до 50 человек
# 7                                  500         Киев       до 10 человек
# 8                                  550      Харьков  свыше 1000 человек
# 11                                1500         Киев  свыше 1000 человек
# 12                                 200         Киев       до 50 человек
Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...   5.0
#
#       current_job_exp  salary
# 2                 1.0    2500
# 3                 4.0    2000
# 4                 0.5    4500
# 6                 0.0     600
# 7                 1.0    3300
# 8                 0.5     550
# 11                1.0    5600
# 12                0.0     800
# 14                1.0    2500
# 15                5.0    2900
# 16                1.0    2875
# 17                1.0     574
# 18                0.5    3300
# 24                1.0    2800
# 35                1.0     350
# 40                1.5     450
# 44                4.0    3400
# 52                4.0    4500
# 54                3.0    3000
# 111              10.0    4150
# 219               4.0    3000
# 480               7.0    4300
# 730               5.0    4000
# 733               2.0    4500
# 1135              5.0    3600
# 1706              0.0    2700
# 2049              0.5     400
# 2911              0.0    7000
# 2936              0.5     400
# 3097              1.0     600
# 4098              7.0    3000
# 4315              0.5     385
# 5105              4.0    4000
# 6304              0.0     500
# 6712              1.0    2000
# 7004              5.0    2500

# %%
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", 
# виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у 
# стовпчику "Зарплата.в.місяць"

df_new = df
df_new = df.groupby(['Должность'])['Зарплата.в.месяц'].agg([np.min, np.max])
df_new
# Out:
#                                amin   amax
# Должность
# Data Scientist / Data Analyst  2700   2700
# DevOps                         7000   7000
# ERP / CRM                      2000   2000
# HTML coder                      385    600
# Junior Software Engineer         75   2600
# Product Manager                3000   3000
# Senior Software Engineer        350   9200
# Software Engineer               100   7000
# System Architect                400  10000
# Team lead                      2500   4000
# Technical Lead                  500  18000

# %%
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. 
# Використовуйте її для методу apply та створіть новий стовпчик "avg"


def fill_avg_salary(salary):
    return salary.mean()

df_new['avg'] = df_new.apply(fill_avg_salary, axis=1)
df_new
# Out:
#                                amin   amax     avg
# Должность
# Data Scientist / Data Analyst  2700   2700  2700.0
# DevOps                         7000   7000  7000.0
# ERP / CRM                      2000   2000  2000.0
# HTML coder                      385    600   492.5
# Junior Software Engineer         75   2600  1337.5
# Product Manager                3000   3000  3000.0
# Senior Software Engineer        350   9200  4775.0
# Software Engineer               100   7000  3550.0
# System Architect                400  10000  5200.0
# Team lead                      2500   4000  3250.0
# Technical Lead                  500  18000  9250.0

# %%
# Створіть описову статистику за допомогою методу describe для нового стовпчика.

df_new['avg'].describe()
# Out:
# count      11.000000
# mean     3868.636364
# std      2554.599128
# min       492.500000
# 25%      2350.000000
# 50%      3250.000000
# 75%      4987.500000
# max      9250.000000
# Name: avg, dtype: float64

# %%
# Збережіть отриману таблицю в CSV файл

df_new.to_csv('2017_jun_final_new.csv', encoding='utf8')

# %%
#====================================
#====================================Домашнє завдання модуля 3 (візуалізаціія даних)
#====================================

# %%
# %matplotlib inline
df_2017_jun_final_new = pd.read_csv("2017_jun_final_new.csv")
sns.set_style('darkgrid')
plt.bar(df_2017_jun_final_new['Должность'], df_2017_jun_final_new['avg'])
plt.title('Діаграма залежності середньої зарплати від спеціальності')
plt.tick_params(labelrotation = 90)
plt.show()

# %%
# %matplotlib inline
sns.scatterplot(x='Должность', y='avg', data=df_2017_jun_final_new)
plt.tick_params(labelrotation = 90)
plt.show()

# %%
# %matplotlib inline
sns.stripplot(x='Должность', y='avg', data=df_2017_jun_final_new)
plt.tick_params(labelrotation = 90)
plt.show()
